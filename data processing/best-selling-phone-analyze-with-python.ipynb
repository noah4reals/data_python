# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top-100list-of-bestselling-mobile-phones/List of best-selling mobile phones.csv

# %%
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
phonedata = pd.read_csv("../input/top-100list-of-bestselling-mobile-phones/List of best-selling mobile phones.csv")

# %%
phonedata.dtypes
# Out:
# Rank             float64
# Manufacturer      object
# Model             object
# Form factor       object
# Smartphone?       object
# Year               int64
# Million Units     object
# dtype: object

# %%
phonedata.head()
# Out:
#    Rank Manufacturer                         Model  Form factor Smartphone?  \
# 0   1.0        Nokia                          1100          Bar          No
# 1   2.0        Nokia                          1110          Bar          No
# 2   3.0        Apple    iPhone 6 and iPhone 6 Plus  Touchscreen         Yes
# 3   4.0        Nokia        105 (2013), 105 (2015)          Bar          No
# 4   5.0        Apple  iPhone 6S and iPhone 6S Plus  Touchscreen         Yes
#
#    Year         Million Units
# 0  2003          250[4][1][5]
# 1  2005        247.5[4][1][6]
# 2  2014                224[7]
# 3  2013                200[8]
# 4  2015  174.1[9][10][11][12]

# %% [markdown]
# #### how many column and rows we have?

# %%
phonedata.shape
# Out:
# (115, 7)

# %% [markdown]
# ## Group the data by phone names of each mark or manufacturer

# %%
phonedata['Manufacturer'].nunique()
# Out:
# 14

# %% [markdown]
# ## so now let's analyze every mark and it's best selling phones and how much units they sold.

# %%
# Group the phonedata DataFrame by 'Manufacturer'
group_phones = phonedata.groupby('Manufacturer')

# Iterate over the groups
for manufacturer, group in group_phones:
    # Perform operations on each group
    print("Manufacturer:", manufacturer)
    print(group)
    print()
# Out:
# Manufacturer: Apple
#       Rank Manufacturer                                              Model  \
# 2      3.0        Apple                         iPhone 6 and iPhone 6 Plus
# 4      5.0        Apple                       iPhone 6S and iPhone 6S Plus
# 5      6.0        Apple                                          iPhone 5S
# 7      8.0        Apple                         iPhone 7 and iPhone 7 Plus
# 8      9.0        Apple     iPhone 11, iPhone 11 Pro and iPhone 11 Pro Max
# 9     10.0        Apple             iPhone XR, iPhone XS and iPhone XS Max
# 14    15.0        Apple                                           iPhone 5
# 19    20.0        Apple                         iPhone 8 and iPhone 8 Plus
# 20    21.0        Apple  Apple iPhone 12, iPhone 12 mini, iPhone 12 Pro...
# 27    28.0        Apple                                           iPhone X
# 28    29.0        Apple                                          iPhone 4S
# 35    36.0        Apple                                           iPhone 4
# 44    45.0        Apple                                         iPhone 3GS
# 52    53.0        Apple                                  iPhone 12 Pro Max
# 57    58.0        Apple                         iPhone SE (2nd generation)
# 103  104.0        Apple                                             iPhone
#
#      Form factor Smartphone?  Year              Million Units
# 2    Touchscreen         Yes  2014                     224[7]
# 4    Touchscreen         Yes  2015       174.1[9][10][11][12]
# 5    Touchscreen         Yes  2013                   164.5[7]
# 7    Touchscreen         Yes  2016  159.9[11][14][15][16][17]
# 8    Touchscreen         Yes  2019          159.2[18][19][20]
# 9    Touchscreen         Yes  2018              151.1[21][19]
# 14   Touchscreen         Yes  2012                   146.2[7]
# 19   Touchscreen         Yes  2017  124.7[23][19][16][24][25]
# 20   Touchscreen         Yes  2020                    100[18]
# 27   Touchscreen         Yes  2017                     63[29]
# 28   Touchscreen         Yes  2011               60[4][6][30]
# 35   Touchscreen         Yes  2010                     50[30]
# 44   Touchscreen         Yes  2009                      35[6]
# 52   Touchscreen         Yes  2020                     29[18]
# 57   Touchscreen         Yes  2020                   24.2[42]
# 103  Touchscreen         Yes  2007                      6[74]
#
# Manufacturer: Google
#       Rank Manufacturer               Model  Form factor Smartphone?  Year  \
# 112  113.0       Google  Pixel and Pixel XL  Touchscreen         Yes  2016
#
#     Million Units
# 112       2.1[81]
#
# Manufacturer: HTC
#     Rank Manufacturer        Model  Form factor Smartphone?  Year  \
# 68  69.0          HTC  Thunderbolt  Touchscreen         Yes  2011
#
#    Million Units
# 68        16[30]
#
# Manufacturer: Huawei
#     Rank Manufacturer                      Model  Form factor Smartphone?  \
# 45  46.0       Huawei  P20, P20 Pro and P20 Lite  Touchscreen         Yes
# 63  64.0       Huawei            P30 and P30 Pro  Touchscreen         Yes
# 65  66.0       Huawei    Mate 10 and Mate 10 Pro  Touchscreen         Yes
# 66  67.0       Huawei    Mate 20 and Mate 20 Pro  Touchscreen         Yes
# 69  70.0       Huawei                     Mate 9  Touchscreen         Yes
# 83  84.0       Huawei    Mate 30 and Mate 30 Pro  Touchscreen         Yes
#
#     Year Million Units
# 45  2018    32[36][19]
# 63  2019        20[49]
# 65  2017        17[50]
# 66  2018        17[49]
# 69  2016      15.8[50]
# 83  2019        12[54]
#
# Manufacturer: LG
#       Rank Manufacturer             Model  Form factor Smartphone?  Year  \
# 48    49.0           LG             KP100          Bar          No  2008
# 60    61.0           LG  Chocolate VX8500       Slider          No  2006
# 82    83.0           LG    Cookie (KP500)  Touchscreen          No  2009
# 87    88.0           LG             Shine       Slider          No  2008
# 92    93.0           LG                G3  Touchscreen         Yes  2014
# 104  105.0           LG    Viewty (KU990)          Bar          No  2007
# 110  111.0           LG                G2  Touchscreen         Yes  2013
#
#           Million Units
# 48               30[37]
# 60   21[43][44][45][46]
# 82           13[52][53]
# 87               10[59]
# 92       10[65][66][67]
# 104               5[75]
# 110           3[77][78]
#
# Manufacturer: LeTV
#       Rank Manufacturer        Model  Form factor Smartphone?  Year  \
# 111  112.0         LeTV  LeEco Le 1s  Touchscreen         Yes  2016
#
#     Million Units
# 111     3[79][80]
#
# Manufacturer: Motorola
#     Rank Manufacturer         Model  Form factor Smartphone?  Year  \
# 16  17.0     Motorola       RAZR V3   Flip phone          No  2004
# 29  30.0     Motorola       StarTAC   Flip phone          No  1996
# 30  31.0     Motorola          C200          Bar          No  2003
# 31  32.0     Motorola          C139          Bar          No  2005
# 81  82.0     Motorola  Droid Bionic  Touchscreen         Yes  2011
#
#    Million Units
# 16     130[4][6]
# 29      60[4][6]
# 30         60[6]
# 31        60[30]
# 81        13[30]
#
# Manufacturer: Nokia
#       Rank Manufacturer                   Model   Form factor Smartphone?  \
# 0      1.0        Nokia                    1100           Bar          No
# 1      2.0        Nokia                    1110           Bar          No
# 3      4.0        Nokia  105 (2013), 105 (2015)           Bar          No
# 6      7.0        Nokia                    3210           Bar          No
# 10    11.0        Nokia                    6600           Bar         Yes
# 11    12.0        Nokia                    1200           Bar          No
# 12    13.0        Nokia                    5230   Touchscreen         Yes
# 15    16.0        Nokia   2600 (2610/2626/2630)           Bar          No
# 17    18.0        Nokia        1600 (1650/1661)           Bar          No
# 18    19.0        Nokia             3310 (3330)           Bar          No
# 21    22.0        Nokia             1208 (1209)           Bar          No
# 22    23.0        Nokia                    1280           Bar          No
# 23    24.0        Nokia        6010 (6020/6030)           Bar          No
# 26    27.0        Nokia        5130 (5220/5310)           Bar          No
# 33    34.0        Nokia             3100 (3120)           Bar          No
# 34    35.0        Nokia             6230 (6233)           Bar          No
# 36    37.0        Nokia                    6300           Bar          No
# 38    39.0        Nokia           N70 (N72/N73)           Bar         Yes
# 43    44.0        Nokia                    2650    Flip phone          No
# 50    51.0        Nokia             5200 (5300)        Slider          No
# 61    62.0        Nokia                    2100           Bar          No
# 72    73.0        Nokia        5610 XpressMusic        Slider          No
# 73    74.0        Nokia        5800 XpressMusic   Touchscreen         Yes
# 74    75.0        Nokia                     E71  Keyboard bar         Yes
# 86    87.0        Nokia                     N95        Slider         Yes
# 109  110.0        Nokia                  N-Gage          Taco         Yes
# 114  115.0        Nokia                     N97   Tilt slider         Yes
#
#      Year     Million Units
# 0    2003      250[4][1][5]
# 1    2005    247.5[4][1][6]
# 3    2013            200[8]
# 6    1999     161[1][6][13]
# 10   2003         150[4][1]
# 11   2007      150[4][1][6]
# 12   2009      150[4][1][6]
# 15   2004   135[4][1][6][5]
# 17   2005   130[4][1][6][5]
# 18   2000  126[4][1][6][22]
# 21   2007      100[4][1][6]
# 22   2010           100[26]
# 23   2004       75[4][6][5]
# 26   2007          65[4][6]
# 33   2003             50[6]
# 34   2004             50[6]
# 36   2006            47[32]
# 38   2005         45[30][5]
# 43   2004             35[6]
# 50   2006             30[5]
# 61   2003        20[47][13]
# 72   2007             15[5]
# 73   2008             15[5]
# 74   2008             15[5]
# 86   2007            10[58]
# 109  2003              3[5]
# 114  2009              2[5]
#
# Manufacturer: Oppo
#       Rank Manufacturer    Model  Form factor Smartphone?  Year Million Units
# 96    97.0         Oppo       A5  Touchscreen         Yes  2019       9.7[69]
# 100  101.0         Oppo  F1 Plus  Touchscreen         Yes  2016         7[72]
#
# Manufacturer: Palm
#       Rank Manufacturer   Model   Form factor Smartphone?  Year Million Units
# 113  114.0         Palm  Centro  Keyboard bar         Yes  2007         2[82]
#
# Manufacturer: Research In Motion (RIM)
#     Rank              Manufacturer             Model Form factor Smartphone?  \
# 78  79.0  Research In Motion (RIM)  BlackBerry Pearl         Bar         Yes
#
#     Year Million Units
# 78  2006        15[30]
#
# Manufacturer: Samsung
#       Rank Manufacturer                                         Model  \
# 13    14.0      Samsung                                         E1100
# 24    25.0      Samsung            Galaxy S III and Galaxy S III Mini
# 25    26.0      Samsung                                     Galaxy S4
# 32    33.0      Samsung                  Galaxy S7 and Galaxy S7 edge
# 37    38.0      Samsung                  Galaxy S6 and Galaxy S6 edge
# 39    40.0      Samsung                      Galaxy S8 and Galaxy S8+
# 40    41.0      Samsung                                   Galaxy S II
# 41    42.0      Samsung       Galaxy S10, Galaxy S10+ and Galaxy S10e
# 42    43.0      Samsung                      Galaxy S9 and Galaxy S9+
# 46    47.0      Samsung                                    Galaxy A10
# 47    48.0      Samsung                                          E250
# 49    50.0      Samsung                                Galaxy Note II
# 53    54.0      Samsung  Galaxy S20, Galaxy S20+ and Galaxy S20 Ultra
# 54    55.0      Samsung                                      Galaxy S
# 55    56.0      Samsung                       Galaxy Grand Prime Plus
# 56    57.0      Samsung                                    Galaxy A50
# 58    59.0      Samsung                                    Galaxy A51
# 59    60.0      Samsung                                    Galaxy A20
# 64    65.0      Samsung                                   Galaxy A21s
# 67    68.0      Samsung                                    Galaxy A01
# 70    71.0      Samsung                                    Galaxy A11
# 71    72.0      Samsung                                Galaxy J2 Core
# 80    81.0      Samsung  Galaxy S21, Galaxy S21+ and Galaxy S21 Ultra
# 84    85.0      Samsung                              Galaxy S22 Ultra
# 85    86.0      Samsung                                      SGH-E700
# 88    89.0      Samsung                       Star/Tocco Lite (S5230)
# 89    90.0      Samsung                                   Galaxy Note
# 91    92.0      Samsung                                 Galaxy Note 3
# 93    94.0      Samsung                                 Galaxy Note 8
# 95    96.0      Samsung                                 Galaxy S20 FE
# 97    98.0      Samsung                                 Galaxy Note 9
# 98    99.0      Samsung                                    Galaxy A30
# 102  103.0      Samsung                                    Galaxy J4+
# 105  106.0      Samsung                                    Galaxy J6+
# 106  107.0      Samsung                                 Galaxy Note 4
# 107  108.0      Samsung                                   Galaxy A10s
# 108  109.0      Samsung                                   Galaxy A30s
#
#      Form factor Smartphone?  Year Million Units
# 13           Bar          No  2009        150[4]
# 24   Touchscreen         Yes  2012        70[27]
# 25   Touchscreen         Yes  2013        70[28]
# 32   Touchscreen         Yes  2016        55[31]
# 37   Touchscreen         Yes  2015        45[33]
# 39   Touchscreen         Yes  2017        41[34]
# 40   Touchscreen         Yes  2011         40[6]
# 41   Touchscreen         Yes  2019        37[35]
# 42   Touchscreen         Yes  2018      35.4[19]
# 46   Touchscreen         Yes  2019      30.3[19]
# 47        Slider          No  2006        30[30]
# 49   Touchscreen         Yes  2012        30[38]
# 53   Touchscreen         Yes  2020        28[40]
# 54   Touchscreen         Yes  2010        25[41]
# 55   Touchscreen         Yes  2016      24.2[19]
# 56   Touchscreen         Yes  2019      24.2[19]
# 58   Touchscreen         Yes  2019      23.2[42]
# 59   Touchscreen         Yes  2019      23.1[19]
# 64   Touchscreen         Yes  2020      19.4[42]
# 67   Touchscreen         Yes  2019      16.9[42]
# 70   Touchscreen         Yes  2020      15.3[42]
# 71   Touchscreen         Yes  2018      15.2[19]
# 80   Touchscreen         Yes  2021      13.5[40]
# 84   Touchscreen         Yes  2022  10.9[55][56]
# 85    Flip phone          No  2003        10[57]
# 88   Touchscreen          No  2009        10[60]
# 89   Touchscreen         Yes  2011    10[61][62]
# 91   Touchscreen         Yes  2013        10[64]
# 93   Touchscreen         Yes  2017        10[68]
# 95   Touchscreen         Yes  2020    10[70][71]
# 97   Touchscreen         Yes  2018       9.6[68]
# 98   Touchscreen         Yes  2019       9.2[69]
# 102  Touchscreen         Yes  2018       6.4[73]
# 105  Touchscreen         Yes  2018       4.9[73]
# 106  Touchscreen         Yes  2014       4.5[76]
# 107  Touchscreen         Yes  2019       3.9[73]
# 108  Touchscreen         Yes  2019       3.4[73]
#
# Manufacturer: Sony Ericsson
#     Rank   Manufacturer        Model Form factor Smartphone?  Year  \
# 75  76.0  Sony Ericsson  K300 (K310)         Bar          No  2004
# 76  77.0  Sony Ericsson         K750         Bar          No  2005
# 77  78.0  Sony Ericsson  W800 (W810)         Bar          No  2006
#
#    Million Units
# 75    15[30][51]
# 76        15[30]
# 77    15[30][51]
#
# Manufacturer: Xiaomi
#       Rank Manufacturer                              Model  Form factor  \
# 51    52.0       Xiaomi  Redmi Note 8 and Redmi Note 8 Pro  Touchscreen
# 62    63.0       Xiaomi  Redmi Note 7 and Redmi Note 7 Pro  Touchscreen
# 79    80.0       Xiaomi                   Redmi Note 9 Pro  Touchscreen
# 90    91.0       Xiaomi                               Mi 2  Touchscreen
# 94    95.0       Xiaomi                           Redmi 6A  Touchscreen
# 99   100.0       Xiaomi                           Redmi 8A  Touchscreen
# 101  102.0       Xiaomi                            Redmi 8  Touchscreen
#
#     Smartphone?  Year Million Units
# 51          Yes  2019        30[39]
# 62          Yes  2019        20[48]
# 79          Yes  2020        15[42]
# 90          Yes  2012        10[63]
# 94          Yes  2019        10[69]
# 99          Yes  2019       7.3[20]
# 101         Yes  2019       6.8[20]

# %% [markdown]
# ## how much every mark have sold in total

# %% [markdown]
# #### Group the phonedata DataFrame by 'Manufacturer' with 'million unit' column

# %%
unit_by_manufacturer = phonedata.groupby('Manufacturer')['Million Units'].sum()

print(unit_by_manufacturer)
# Out:
# Manufacturer
# Apple                       224[7]174.1[9][10][11][12]164.5[7]159.9[11][14...
# Google                                                                2.1[81]
# HTC                                                                    16[30]
# Huawei                             32[36][19]20[49]17[50]17[49]15.8[50]12[54]
# LG                          30[37]21[43][44][45][46]13[52][53]10[59]10[65]...
# LeTV                                                                3[79][80]
# Motorola                                   130[4][6]60[4][6]60[6]60[30]13[30]
# Nokia                       250[4][1][5]247.5[4][1][6]200[8]161[1][6][13]1...
# Oppo                                                             9.7[69]7[72]
# Palm                                                                    2[82]
# Research In Motion (RIM)                                               15[30]
# Samsung                     150[4]70[27]70[28]55[31]45[33]41[34]40[6]37[35...
# Sony Ericsson                                      15[30][51]15[30]15[30][51]
# Xiaomi                           30[39]20[48]15[42]10[63]10[69]7.3[20]6.8[20]
# Name: Million Units, dtype: object

# %%
plt.plot(phonedata["Million Units"], phonedata["Manufacturer"],)
plt.show()

# %% [markdown]
# ## lets see how many phone models each year have sold for each Models.

# %%
# Group the phonedata DataFrame by 'Year','Million Units' and 'Model'
unit_sold_by_year = phonedata.groupby('Year')[['Million Units', 'Model']].sum()

print(unit_sold_by_year)
# Out:
#                                           Million Units  \
# Year
# 1996                                           60[4][6]
# 1999                                      161[1][6][13]
# 2000                                   126[4][1][6][22]
# 2003  250[4][1][5]150[4][1]60[6]50[6]20[47][13]10[57...
# 2004  135[4][1][6][5]130[4][6]75[4][6][5]50[6]35[6]1...
# 2005  247.5[4][1][6]130[4][1][6][5]60[30]45[30][5]15...
# 2006  47[32]30[30]30[5]21[43][44][45][46]15[30][51]1...
# 2007  150[4][1][6]100[4][1][6]65[4][6]15[5]10[58]6[7...
# 2008                             30[37]15[5]15[5]10[59]
# 2009        150[4][1][6]150[4]35[6]13[52][53]10[60]2[5]
# 2010                                100[26]50[30]25[41]
# 2011            60[4][6][30]40[6]16[30]13[30]10[61][62]
# 2012                         146.2[7]70[27]30[38]10[63]
# 2013                200[8]164.5[7]70[28]10[64]3[77][78]
# 2014                        224[7]10[65][66][67]4.5[76]
# 2015                         174.1[9][10][11][12]45[33]
# 2016  159.9[11][14][15][16][17]55[31]24.2[19]15.8[50...
# 2017  124.7[23][19][16][24][25]63[29]41[34]17[50]10[68]
# 2018  151.1[21][19]35.4[19]32[36][19]17[49]15.2[19]9...
# 2019  159.2[18][19][20]37[35]30.3[19]30[39]24.2[19]2...
# 2020  100[18]29[18]28[40]24.2[42]19.4[42]15.3[42]15[...
# 2021                                           13.5[40]
# 2022                                       10.9[55][56]
#
#                                                   Model
# Year
# 1996                                            StarTAC
# 1999                                               3210
# 2000                                        3310 (3330)
# 2003          11006600C2003100 (3120)2100SGH-E700N-Gage
# 2004  2600 (2610/2626/2630)RAZR V36010 (6020/6030)62...
# 2005          11101600 (1650/1661)C139N70 (N72/N73)K750
# 2006  6300E2505200 (5300)Chocolate VX8500W800 (W810)...
# 2007  12001208 (1209)5130 (5220/5310)5610 XpressMusi...
# 2008                      KP1005800 XpressMusicE71Shine
# 2009  5230E1100iPhone 3GSCookie (KP500)Star/Tocco Li...
# 2010                               1280iPhone 4Galaxy S
# 2011  iPhone 4SGalaxy S IIThunderboltDroid BionicGal...
# 2012  iPhone 5Galaxy S III and Galaxy S III MiniGala...
# 2013  105 (2013), 105 (2015)iPhone 5SGalaxy S4Galaxy...
# 2014          iPhone 6 and iPhone 6 PlusG3Galaxy Note 4
# 2015  iPhone 6S and iPhone 6S PlusGalaxy S6 and Gala...
# 2016  iPhone 7 and iPhone 7 PlusGalaxy S7 and Galaxy...
# 2017  iPhone 8 and iPhone 8 PlusiPhone XGalaxy S8 an...
# 2018  iPhone XR, iPhone XS and iPhone XS MaxGalaxy S...
# 2019  iPhone 11, iPhone 11 Pro and iPhone 11 Pro Max...
# 2020  Apple iPhone 12, iPhone 12 mini, iPhone 12 Pro...
# 2021       Galaxy S21, Galaxy S21+ and Galaxy S21 Ultra
# 2022                                   Galaxy S22 Ultra

# %% [markdown]
# ### as we see it started with Model 'StarTAC' in 1996 and the last is 'Galaxy S22 Ultra' in 2022

# %%
phonedata.plot(kind='scatter',
        y='Manufacturer',
        x='Year',
        color='red', figsize=(9,6))
# Out:
# <Axes: xlabel='Year', ylabel='Manufacturer'>

# %% [markdown]
# ### lets see which of the years have the most ranking, which let us see when most phones were bought

# %%
phonedata.plot(kind='hexbin', x='Year', y='Rank', gridsize=10, figsize=(10,6))
# Out:
# <Axes: xlabel='Year', ylabel='Rank'>

# %%
phonedata.plot(kind='area',
       y='Rank',
      x='Manufacturer',
      color='blue',stacked=False, figsize=(15,10))
# Out:
# <Axes: xlabel='Manufacturer'>
